# %%
import pandas as pd
import odo
from collections import OrderedDict
from datashape import Record
from sqlalchemy import *

# %%
def prepare_for_copy(table_name, frame, metadata):
    shape = odo.discover(frame)
    od = OrderedDict(shape.measure.fields)
    for key in od:
        type_name = str(od[key])
        if not type_name.startswith('?'):
            od[key] = odo.dshape('?{}'.format(type_name)) 
    target_shape = odo.dshape([shape.parameters[0], Record(od)])
    target_table = odo.backends.sql.dshape_to_table(table_name, target_shape, metadata=metadata)
    return (target_shape, target_table)

# %%
engine = create_engine('sqlite:///local-data/budge.sqlite')
metadata = MetaData(bind=engine)

# %%
ec2 = pd.read_csv('/Users/ashapoch/Temp/aws-offers/AmazonEC2.csv', low_memory=False)

# %%
target_shape, target_table = prepare_for_copy('AmazonEC2', ec2, metadata)

# %%
odo.odo(ec2, target_table, dshape=target_shape)
# Out:
# Table('AmazonEC2', MetaData(bind=Engine(sqlite:///local-data/budge.sqlite)), Column('SKU', Text(), table=<AmazonEC2>), Column('OfferTermCode', Text(), table=<AmazonEC2>), Column('RateCode', Text(), table=<AmazonEC2>), Column('TermType', Text(), table=<AmazonEC2>), Column('PriceDescription', Text(), table=<AmazonEC2>), Column('EffectiveDate', Text(), table=<AmazonEC2>), Column('StartingRange', FLOAT(), table=<AmazonEC2>), Column('EndingRange', FLOAT(), table=<AmazonEC2>), Column('Unit', Text(), table=<AmazonEC2>), Column('PricePerUnit', FLOAT(), table=<AmazonEC2>), Column('Currency', Text(), table=<AmazonEC2>), Column('LeaseContractLength', Text(), table=<AmazonEC2>), Column('PurchaseOption', Text(), table=<AmazonEC2>), Column('OfferingClass', Text(), table=<AmazonEC2>), Column('Product_Family', Text(), table=<AmazonEC2>), Column('serviceCode', Text(), table=<AmazonEC2>), Column('Location', Text(), table=<AmazonEC2>), Column('Location_Type', Text(), table=<AmazonEC2>), Column('Instance_Type', Text(), table=<AmazonEC2>), Column('Current_Generation', Text(), table=<AmazonEC2>), Column('Instance_Family', Text(), table=<AmazonEC2>), Column('vCPU', FLOAT(), table=<AmazonEC2>), Column('Physical_Processor', Text(), table=<AmazonEC2>), Column('Clock_Speed', Text(), table=<AmazonEC2>), Column('Memory', Text(), table=<AmazonEC2>), Column('Storage', Text(), table=<AmazonEC2>), Column('Network_Performance', Text(), table=<AmazonEC2>), Column('Processor_Architecture', Text(), table=<AmazonEC2>), Column('Storage_Media', Text(), table=<AmazonEC2>), Column('Volume_Type', Text(), table=<AmazonEC2>), Column('Max_Volume_Size', Text(), table=<AmazonEC2>), Column('Max_IOPS_volume', Text(), table=<AmazonEC2>), Column('Max_IOPS_Burst_Performance', Text(), table=<AmazonEC2>), Column('Max_throughput_volume', Text(), table=<AmazonEC2>), Column('Provisioned', Text(), table=<AmazonEC2>), Column('Tenancy', Text(), table=<AmazonEC2>), Column('EBS_Optimized', Text(), table=<AmazonEC2>), Column('Operating_System', Text(), table=<AmazonEC2>), Column('License_Model', Text(), table=<AmazonEC2>), Column('Group', Text(), table=<AmazonEC2>), Column('Group_Description', Text(), table=<AmazonEC2>), Column('Transfer_Type', Text(), table=<AmazonEC2>), Column('From_Location', Text(), table=<AmazonEC2>), Column('From_Location_Type', Text(), table=<AmazonEC2>), Column('To_Location', Text(), table=<AmazonEC2>), Column('To_Location_Type', Text(), table=<AmazonEC2>), Column('usageType', Text(), table=<AmazonEC2>), Column('operation', Text(), table=<AmazonEC2>), Column('Comments', Text(), table=<AmazonEC2>), Column('Dedicated_EBS_Throughput', Text(), table=<AmazonEC2>), Column('Enhanced_Networking_Supported', Text(), table=<AmazonEC2>), Column('GPU', FLOAT(), table=<AmazonEC2>), Column('Instance_Capacity_10xlarge', FLOAT(), table=<AmazonEC2>), Column('Instance_Capacity_2xlarge', FLOAT(), table=<AmazonEC2>), Column('Instance_Capacity_4xlarge', FLOAT(), table=<AmazonEC2>), Column('Instance_Capacity_8xlarge', FLOAT(), table=<AmazonEC2>), Column('Instance_Capacity_large', FLOAT(), table=<AmazonEC2>), Column('Instance_Capacity_medium', FLOAT(), table=<AmazonEC2>), Column('Instance_Capacity_xlarge', FLOAT(), table=<AmazonEC2>), Column('Intel_AVX_Available', Text(), table=<AmazonEC2>), Column('Intel_AVX2_Available', Text(), table=<AmazonEC2>), Column('Intel_Turbo_Available', Text(), table=<AmazonEC2>), Column('Physical_Cores', FLOAT(), table=<AmazonEC2>), Column('Pre_Installed_S_W', Text(), table=<AmazonEC2>), Column('Processor_Features', Text(), table=<AmazonEC2>), Column('Sockets', FLOAT(), table=<AmazonEC2>), schema=None)

# %%
ec2_sql = pd.read_sql('AmazonEC2', 'sqlite:///local-data/budge.sqlite', 
                      coerce_float=True,
                      parse_dates={'EffectiveDate': '%Y-%m-%d'})

# %%
def column_values(frame):
    for column in frame.columns:
        print(column, frame[column].unique())

# %%
column_values(ec2_sql)
# Out:
# SKU ['YQHNG5NBWUE3D67S' 'EYDF9FPAH9XHZRBR' 'WQ8JS87GX5QJ6VS4' ...,
#  '8N98ZZ39AXPEH5HG' 'KSH9QSRS8SVAAQXM' 'F6SJVEQRD2XCWRMK']
# OfferTermCode ['4NA7Y494T4' 'Z2E3P23VKM' 'JRTCKXETXF' 'HU7G6KETJZ' '6QCMYABX3D'
#  '38NPMPTW36' 'R5XV2EPZQZ' 'MZU6U2429S' 'NQ3QZPMQV9']
# RateCode ['YQHNG5NBWUE3D67S.4NA7Y494T4.6YS6EN2CT7'
#  'EYDF9FPAH9XHZRBR.Z2E3P23VKM.6YS6EN2CT7'
#  'WQ8JS87GX5QJ6VS4.JRTCKXETXF.6YS6EN2CT7' ...,
#  'PHDC7MBYXDRUFJ3W.JRTCKXETXF.6YS6EN2CT7'
#  '6YGF9V4VPXM2PCWU.6QCMYABX3D.6YS6EN2CT7'
#  'ZSEV6RFE6GFENUNZ.MZU6U2429S.2TG2D8R56U']
# TermType ['Reserved' 'OnDemand']
# PriceDescription [ 'Red Hat Enterprise Linux (Amazon VPC), m4.xlarge instance-hours used this month'
#  'Windows with SQL Server Web (Amazon VPC), r4.16xlarge instance-hours used this month'
#  '$5.138 per Dedicated Windows i2.4xlarge Instance Hour' ...,
#  '$0.342 per Dedicated Usage SUSE c4.xlarge Instance Hour'
#  '$1.089 per On Demand Windows BYOL m4.4xlarge Instance Hour'
#  '$0.772 per On Demand Windows BYOL g2.2xlarge Instance Hour']
# EffectiveDate ['2016-11-30T00:00:00.000000000' '2016-10-31T00:00:00.000000000'
#  '2017-03-01T00:00:00.000000000' '2015-04-30T00:00:00.000000000'
#  '2017-02-28T00:00:00.000000000' '2016-09-30T00:00:00.000000000'
#  '2016-08-31T00:00:00.000000000' '2015-12-31T00:00:00.000000000'
#  '2016-06-30T00:00:00.000000000' '2017-01-31T00:00:00.000000000'
#  '2015-05-31T00:00:00.000000000' '2016-07-31T00:00:00.000000000'
#  '2016-01-31T00:00:00.000000000' '2015-06-30T00:00:00.000000000'
#  '2016-05-31T00:00:00.000000000' '2015-11-30T00:00:00.000000000'
#  '2016-12-31T00:00:00.000000000']
# StartingRange [  0.00000000e+00              nan   1.00000000e+00   1.00000000e+02
#    1.02400000e+04   5.12000000e+04   1.53600000e+05]
# EndingRange [             inf              nan   1.00000000e+00   1.00000000e+02
#    1.02400000e+04   5.12000000e+04   1.53600000e+05]
# Unit ['Hrs' 'Quantity' 'hrs' 'GB' 'IOs' 'GB-Mo' 'IOPS-Mo' 'Count' 'LCU-Hrs'
#  'Gbps-hrs']
# PricePerUnit [  2.23000000e-01   7.30700000e+00   5.13820000e+00 ...,   4.87730000e+04
#    4.81890000e+04   3.51900000e+03]
# Currency ['USD']
# LeaseContractLength ['1yr' '3yr' None]
# PurchaseOption ['No Upfront' None 'Partial Upfront' 'All Upfront']
# OfferingClass ['standard' 'convertible' None]
# Product_Family ['Compute Instance' 'Data Transfer' 'System Operation' 'Storage'
#  'Load Balancer-Application' 'NAT Gateway' 'IP Address' 'Dedicated Host'
#  'Load Balancer' 'Storage Snapshot' 'Fee']
# serviceCode ['AmazonEC2' 'AWSDataTransfer']
# Location ['US East (Ohio)' 'EU (Frankfurt)' 'Asia Pacific (Seoul)'
#  'Asia Pacific (Singapore)' 'Asia Pacific (Sydney)' 'US West (Oregon)'
#  'South America (Sao Paulo)' 'US East (N. Virginia)'
#  'US West (N. California)' 'AWS GovCloud (US)' 'Asia Pacific (Mumbai)'
#  'EU (Ireland)' 'Asia Pacific (Tokyo)' 'Canada (Central)' 'EU (London)'
#  None]
# Location_Type ['AWS Region' None]
# Instance_Type ['m4.xlarge' 'r4.16xlarge' 'i2.4xlarge' 'm3.2xlarge' 'm1.medium'
#  'c4.xlarge' 'c4.4xlarge' 't2.large' 'm4.2xlarge' 'i2.8xlarge' 'm3.xlarge'
#  'i3.large' 'r3.8xlarge' 'd2.4xlarge' 'i3.2xlarge' 't2.medium' 'c3.large'
#  'i2.xlarge' 'r3.xlarge' 'r4.4xlarge' 'r4.2xlarge' 'x1.16xlarge'
#  'c3.8xlarge' 'r3.2xlarge' 'i3.16xlarge' 'm4.large' 't2.micro' 'i3.4xlarge'
#  'c3.2xlarge' 'c3.xlarge' 'r3.large' 'm2.4xlarge' 'm4.10xlarge'
#  'm4.16xlarge' 'd2.2xlarge' 'i3.xlarge' 'i3.8xlarge' 'c3.4xlarge'
#  'x1.32xlarge' 't2.xlarge' 'r4.xlarge' 'r3.4xlarge' 'p2.16xlarge'
#  'r4.8xlarge' 'c4.8xlarge' 'm4.4xlarge' 'd2.xlarge' 'i2.2xlarge'
#  'cc2.8xlarge' 't1.micro' 'g2.2xlarge' 'c1.xlarge' 'c4.2xlarge'
#  'd2.8xlarge' 't2.nano' 'r4.large' 'm3.medium' 'm3.large' 'c4.large' None
#  'c1.medium' 'hs1.8xlarge' 't2.2xlarge' 'm2.2xlarge' 'm1.xlarge' 'm1.large'
#  'p2.8xlarge' 'hi1.4xlarge' 'm1.small' 'm2.xlarge' 'cr1.8xlarge'
#  'p2.xlarge' 'g2.8xlarge' 't2.small' 'cc1.4xlarge' 'd2' 'r4' 'c4' 'm4' 'x1'
#  'c3' 'i2' 'cg1.4xlarge' 'g2' 'p2' 'r3' 'i3' 'm3']
# Current_Generation ['Yes' 'No' None]
# Instance_Family ['General purpose' 'Memory optimized' 'Storage optimized'
#  'Compute optimized' 'GPU instance' 'Micro instances' None]
# vCPU [   4.   64.   16.    8.    1.    2.   32.   40.  128.   36.   nan   17.]
# Physical_Processor ['Intel Xeon E5-2676 v3 (Haswell)' 'Intel Xeon E5-2686 v4 (Broadwell)'
#  'Intel Xeon E5-2670 v2 (Ivy Bridge)'
#  'Intel Xeon E5-2670 v2 (Ivy Bridge/Sandy Bridge)' 'Intel Xeon Family'
#  'Intel Xeon E5-2666 v3 (Haswell)' 'Intel Xeon E5-2676v3 (Haswell)'
#  'Intel Xeon E5-2680 v2 (Ivy Bridge)'
#  'High Frequency Intel Xeon E7-8880 v3 (Haswell)' 'Intel Xeon E5-2670'
#  'Variable' 'Intel Xeon E5-2670 (Sandy Bridge)' None 'Intel Xeon E5-2650'
#  'Intel Xeon x5570']
# Clock_Speed ['2.4  GHz' '2.3 GHz' '2.5 GHz' None '2.9 GHz' 'Up to 3.0 GHz' '2.4 GHz'
#  'Up to 3.3 GHz' '2.8 GHz' '2.6 GHz' '2 GHz']
# Memory ['16 GiB' '488 GiB' '122 GiB' '30 GiB' '3.75 GiB' '7.5 GiB' '8 GiB'
#  '32 GiB' '244 GiB' '15 GiB' '15.25 GiB' '61 GiB' '4 GiB' '30.5 GiB'
#  '976 Gib' '60 GiB' '1 GiB' '68.4 GiB' '160 GiB' '256 GiB' '1,952 Gib'
#  '768 GiB' '64 GiB' '60.5 GiB' '0.613 GiB' '7 GiB' '0.5 GiB' None '1.7 GiB'
#  '117 GiB' '34.2 GiB' '17.1 GiB' '2 GiB' '23 GiB' '22.5 GiB']
# Storage ['EBS only' '4 x 800 SSD' '2 x 80 SSD' '1 x 410' '8 x 800 SSD' '2 x 40 SSD'
#  '2 x 320 SSD' '12 x 2000 HDD' '2 x 16 SSD' '1 x 800 SSD' '1 x 80 SSD'
#  '1 x 1,920' '1 x 160 SSD' '1 x 32 SSD' '2 x 840' '6 x 2000 HDD'
#  '2 x 160 SSD' '2 x 1,920' '1 x 320 SSD' '3 x 2000 HDD' '2 x 800 SSD'
#  '4 x 840' '1 x 60 SSD' '4 x 420' '24 x 2000 HDD' '1 x 4 SSD' None
#  '1 x 350' '24 x 2000' '1 x 850' '2 x 420' '2 x 1024 SSD' '1 x 160'
#  '1 x 420' '2 x 120 SSD' '2 x 840 GB']
# Network_Performance ['High' '20 Gigabit' 'Moderate' 'Low to Moderate' '10 Gigabit'
#  'Up to 10 Gigabit' 'Very Low' 'Low' None]
# Processor_Architecture ['64-bit' '32-bit or 64-bit' None]
# Storage_Media [None 'HDD-backed' 'SSD-backed' 'Amazon S3']
# Volume_Type [None 'Cold HDD' 'Throughput Optimized HDD' 'Provisioned IOPS'
#  'General Purpose' 'Magnetic']
# Max_Volume_Size [None '16 TiB' '1 TiB']
# Max_IOPS_volume [None '250 - based on 1 MiB I/O size' '500 - based on 1 MiB I/O size'
#  '20000' '10000' '40 - 200']
# Max_IOPS_Burst_Performance [None '3000 for volumes <= 1 TiB' 'Hundreds']
# Max_throughput_volume [None '250 MiB/s' '500 MiB/s' '320 MB/sec' '160 MB/sec' '40 - 90 MB/sec']
# Provisioned [None 'No' 'Yes']
# Tenancy ['Dedicated' 'Shared' 'Host' None]
# EBS_Optimized [None 'Yes']
# Operating_System ['RHEL' 'Windows' 'SUSE' 'Linux' None]
# License_Model ['No License required' 'License Included' 'Bring your own license' None]
# Group [None 'EBS I/O Requests' 'ELB:Balancer' 'NGW:NatGateway' 'EBS IOPS'
#  'ElasticIP:Address' 'ElasticIP:AdditionalAddress' 'ElasticIP:Remap'
#  'ELB:Balancing' 'EC2-Dedicated Usage']
# Group_Description [None 'Input/Output Operation'
#  'LoadBalancer hourly usage by Application Load Balancer'
#  'Hourly charge for NAT Gateways' 'IOPS'
#  'Elastic IP address attached to a running instance'
#  'Charge for per GB data processed by NatGateways'
#  'Standard Elastic Load Balancer'
#  'Additional Elastic IP address attached to a running instance'
#  'Charge for per GB data processed by NAT Gateways with provisioned bandwidth'
#  'Elastic IP address remap'
#  'Used Application load balancer capacity units-hr'
#  'Data processed by Elastic Load Balancer'
#  'Per hour and per Gbps charge for NAT Gateways with provisioned bandwidth'
#  'Fee for running at least one Dedicated Instance in the region']
# Transfer_Type [None 'InterRegion Inbound' 'InterRegion Outbound' 'IntraRegion'
#  'AWS Inbound' 'AWS Outbound']
# From_Location [None 'EU (Frankfurt)' 'EU (London)' 'US East (Ohio)'
#  'US East (N. Virginia)' 'Asia Pacific (Tokyo)' 'Asia Pacific (Seoul)'
#  'AWS GovCloud (US)' 'Asia Pacific (Singapore)' 'EU (Ireland)' 'External'
#  'Asia Pacific (Sydney)' 'US West (Oregon)' 'Asia Pacific (Mumbai)'
#  'South America (Sao Paulo)' 'Canada (Central)' 'US West (N. California)']
# From_Location_Type [None 'AWS Region' 'Other']
# To_Location [None 'EU (London)' 'EU (Ireland)' 'AWS GovCloud (US)'
#  'South America (Sao Paulo)' 'Canada (Central)' 'US East (N. Virginia)'
#  'Asia Pacific (Singapore)' 'Asia Pacific (Tokyo)' 'Asia Pacific (Seoul)'
#  'US East (Ohio)' 'Asia Pacific (Mumbai)' 'US West (N. California)'
#  'Asia Pacific (Sydney)' 'US West (Oregon)' 'Amazon CloudFront' 'External'
#  'EU (Frankfurt)']
# To_Location_Type [None 'AWS Region' 'AWS Edge Location' 'Other']
# usageType ['USE2-DedicatedUsage:m4.xlarge' 'EUC1-BoxUsage:r4.16xlarge'
#  'APN2-DedicatedUsage:i2.4xlarge' ..., 'USW2-EBSOptimized:c4.xlarge'
#  'APS2-LCUUsage' 'EU-EBSOptimized:c1.xlarge']
# operation ['RunInstances:0010' 'RunInstances:0202' 'RunInstances:0002'
#  'RunInstances:0006' 'RunInstances:0102' 'RunInstances:000g' 'RunInstances'
#  'RunInstances:0800' None 'Hourly' 'LoadBalancing:Application' 'NatGateway'
#  'LoadBalancing' 'Surcharge']
# Comments [None 'To be made public at the time of LHR launch, 12/13']
# Dedicated_EBS_Throughput ['750 Mbps' '12000 Mbps' None '2000 Mbps' '1000 Mbps' '425 Mbps'
#  '1750 Mbps' '3000 Mbps' '1600 Mbps' '14000 Mbps' '450 Mbps' '3500 Mbps'
#  '4000 Mbps' '10000 Mbps' '850 Mbps' '7000 Mbps' '800 Mbps' '6000 Mbps'
#  '400 Mbps' '500 Mbps']
# Enhanced_Networking_Supported ['Yes' None]
# GPU [ nan  16.   1.   4.]
# Instance_Capacity_10xlarge [ nan   1.]
# Instance_Capacity_2xlarge [ nan   4.   8.   5.]
# Instance_Capacity_4xlarge [ nan   2.   4.]
# Instance_Capacity_8xlarge [ nan   1.   2.]
# Instance_Capacity_large [ nan  32.  16.  22.]
# Instance_Capacity_medium [ nan  32.]
# Instance_Capacity_xlarge [ nan   8.  16.  11.]
# Intel_AVX_Available [None 'Yes']
# Intel_AVX2_Available [None 'Yes']
# Intel_Turbo_Available [None 'Yes']
# Physical_Cores [ nan  24.  32.  20.  64.]
# Pre_Installed_S_W [None 'SQL Web' 'SQL Std' 'SQL Server Enterprise']
# Processor_Features ['Intel AVX; Intel AVX2; Intel Turbo' 'Intel AVX, Intel AVX2, Intel Turbo'
#  'Intel AVX; Intel Turbo' None]
# Sockets [ nan   2.]

# %%
compared_ec2_instances = ec2_sql[(ec2_sql.Product_Family == 'Compute Instance') & 
                                 (ec2_sql.Tenancy == 'Shared') & 
                                 (ec2_sql.Operating_System == 'Linux') &
                                 (ec2_sql.Location == 'US East (Ohio)')]

# %%
column_values(compared_ec2_instances)
# Out:
# SKU ['YQZKQQ43X7CBE4ZD' 'B7KJQVXZZNDAS23N' 'AW2T9CUGJYGQKTY8'
#  '9DMUVQNHGNHC7R92' 'Q236HUQXMUFFR9AN' 'JVT8Z9JR8H2KTMEY'
#  'ZWW6ZZSFWQM7H534' 'C2XHT7MUVASJ7UQ3' '9F7GGKJQGM6J387N'
#  '2N2QH6UEJZ5GUPT8' 'URPTCUXU96S8XJUV' 'PBMCNRQPJ8XA43PT'
6YS6EN2CT7'
#  '9DMUVQNHGNHC7R92.4NA7Y494T4.6YS6EN2CT7'
#  '93HAYG7AFZGMJKJY.HU7G6KETJZ.2TG2D8R56U'
#  'RHW8EAZNVJA4KSWC.MZU6U2429S.2TG2D8R56U'
#  'PBMCNRQPJ8XA43PT.38NPMPTW36.2TG2D8R56U'
#  'JNBD8ZZ5JSFMNNYR.4NA7Y494T4.6YS6EN2CT7'
#  '9DMUVQNHGNHC7R92.38NPMPTW36.2TG2D8R56U'
#  'GSMN37GEEUV2CC27.HU7G6KETJZ.6YS6EN2CT7'
#  'RGU9HRNUAS2TX83W.6QCMYABX3D.6YS6EN2CT7'
#  'PBMCNRQPJ8XA43PT.HU7G6KETJZ.6YS6EN2CT7'
#  '65YDGPXVA9GTBYCA.HU7G6KETJZ.2TG2D8R56U'
#  'J3ASENPUVKBMMQG3.NQ3QZPMQV9.2TG2D8R56U'
#  'GSMN37GEEUV2CC27.6QCMYABX3D.6YS6EN2CT7'
#  '9MXQF8NSPZESJJUW.NQ3QZPMQV9.2TG2D8R56U'
#  'PSAR6KAESEV4S8JY.R5XV2EPZQZ.2TG2D8R56U'
#  'DBBN8V6AE5WQCCGZ.MZU6U2429S.6YS6EN2CT7'
#  'JVT8Z9JR8H2KTMEY.R5XV2EPZQZ.6YS6EN2CT7'
#  'R4CKBWU7M6GSC7QB.4NA7Y494T4.6YS6EN2CT7'
#  'RGU9HRNUAS2TX83W.HU7G6KETJZ.6YS6EN2CT7'
#  'PBMCNRQPJ8XA43PT.6QCMYABX3D.6YS6EN2CT7'
#  '5G4M46QWK9ZC9QDT.R5XV2EPZQZ.6YS6EN2CT7']
# TermType ['Reserved' 'OnDemand']
# PriceDescription ['Upfront Fee'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), t2.large instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r4.large instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), c4.8xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), t2.medium instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), d2.2xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r4.2xlarge instance-hour (or partial hour)'
#  '$0.69 per On Demand Linux d2.xlarge Instance Hour'
#  'Linux/UNIX (Amazon VPC), i3.xlarge reserved instance applied'
#  'Linux/UNIX (Amazon VPC), m4.xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r3.large instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), i3.2xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r4.16xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), r3.4xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), i2.xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), c4.xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), c4.large instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r4.xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), t2.nano instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), i3.8xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), r4.4xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), t2.xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), m4.large instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), c4.4xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r3.2xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), t2.2xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), c4.8xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), x1.16xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r4.4xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), m4.2xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), m4.4xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), d2.4xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), m4.16xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), m4.2xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r4.8xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), r3.xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), x1.32xlarge instance-hours used this month'
#  '$0.133 per On Demand Linux r4.large Instance Hour'
#  'Linux/UNIX (Amazon VPC), c4.xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), t2.micro instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), i3.16xlarge reserved instance applied'
#  'Linux/UNIX (Amazon VPC), t2.micro instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r3.xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r3.8xlarge instance-hour (or partial hour)'
#  '$2.66 per On Demand Linux r3.8xlarge Instance Hour'
#  'Linux/UNIX (Amazon VPC), r4.8xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), i2.4xlarge instance-hours used this month'
#  '$1.248 per On Demand Linux i3.4xlarge Instance Hour'
#  'Linux/UNIX (Amazon VPC), r4.xlarge instance-hours used this month'
#  '$0.853 per On Demand Linux i2.xlarge Instance Hour'
#  'Linux/UNIX (Amazon VPC), i3.large reserved instance applied'
#  'Linux/UNIX (Amazon VPC), d2.8xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), i3.8xlarge reserved instance applied'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), t2.nano instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), i3.xlarge instance-hour (or partial hour)'
#  '$6.820 per On Demand Linux i2.8xlarge Instance Hour'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), t2.medium instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), c4.large instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), r3.large instance-hours used this month'
#  '$0.398 per On Demand Linux c4.2xlarge Instance Hour'
#  'Linux/UNIX (Amazon VPC), x1.16xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), r3.2xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), i2.2xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), d2.xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), m4.xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), i2.xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), m4.10xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), i2.4xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), t2.small instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), t2.small instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), r3.4xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), m4.large instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), i2.2xlarge instance-hour (or partial hour)'
#  '$0.023 per On Demand Linux t2.small Instance Hour'
#  'Linux/UNIX (Amazon VPC), c4.2xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), x1.32xlarge instance-hour (or partial hour)'
#  '$0.012 per On Demand Linux t2.micro Instance Hour'
#  '$1.33 per On Demand Linux r3.4xlarge Instance Hour'
#  'Linux/UNIX (Amazon VPC), r3.8xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), i3.4xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), c4.4xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), m4.4xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), i2.8xlarge instance-hours used this month'
#  'Linux/UNIX (Amazon VPC), i3.2xlarge reserved instance applied'
#  'Linux/UNIX (Amazon VPC), r4.large instance-hours used this month'
#  '$3.410 per On Demand Linux i2.4xlarge Instance Hour'
#  'Linux/UNIX (Amazon VPC), t2.large instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), m4.16xlarge instance-hour (or partial hour)'
#  '$0.431 per On Demand Linux m4.2xlarge Instance Hour'
#  'Linux/UNIX (Amazon VPC), r4.2xlarge instance-hours used this month'
#  '$0.199 per On Demand Linux c4.xlarge Instance Hour'
#  '$0.266 per On Demand Linux r4.xlarge Instance Hour'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), c4.2xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), d2.xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), d2.4xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), i2.8xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), d2.2xlarge instance-hour (or partial hour)'
#  '$0.312 per On Demand Linux i3.xlarge Instance Hour'
#  'Linux/UNIX (Amazon VPC), r4.16xlarge instance-hours used this month'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), t2.xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), m4.10xlarge instance-hour (or partial hour)'
#  'Linux/UNIX (Amazon VPC), i3.4xlarge reserved instance applied'
#  '$1.064 per On Demand Linux r4.4xlarge Instance Hour'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), i3.16xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), t2.2xlarge instance-hour (or partial hour)'
#  '$6.669 per On Demand Linux x1.16xlarge Instance Hour'
#  '$0.047 per On Demand Linux t2.medium Instance Hour'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), d2.8xlarge instance-hour (or partial hour)'
#  'USD 0.0 per Linux/UNIX (Amazon VPC), i3.large instance-hour (or partial hour)'
#  '$0.624 per On Demand Linux i3.2xlarge Instance Hour'
#  '$4.256 per On Demand Linux r4.16xlarge Instance Hour'
#  '$0.532 per On Demand Linux r4.2xlarge Instance Hour'
#  '$0.188 per On Demand Linux t2.xlarge Instance Hour'
#  '$1.591 per On Demand Linux c4.8xlarge Instance Hour'
#  '$0.215 per On Demand Linux m4.xlarge Instance Hour'
#  '$3.447 per On Demand Linux m4.16xlarge Instance Hour'
#  '$0.1 per On Demand Linux c4.large Instance Hour'
#  '$2.496 per On Demand Linux i3.8xlarge Instance Hour'
#  '$0.166 per On Demand Linux r3.large Instance Hour'
#  '$0.094 per On Demand Linux t2.large Instance Hour'
#  '$5.52 per On Demand Linux d2.8xlarge Instance Hour'
#  '$4.992 per On Demand Linux i3.16xlarge Instance Hour'
#  '$13.338 per On Demand Linux x1.32xlarge Instance Hour'
#  '$1.705 per On Demand Linux i2.2xlarge Instance Hour'
#  '$0.156 per On Demand Linux i3.large Instance Hour'
#  '$0.108 per On Demand Linux m4.large Instance Hour'
#  '$2.155 per On Demand Linux m4.10xlarge Instance Hour'
#  '$0.665 per On Demand Linux r3.2xlarge Instance Hour'
#    6.32000000e-01   6.65000000e-01   1.14900000e+00   1.71430000e+04
#    2.92100000e+03   5.19500000e+03   4.37600000e+03   5.02000000e-01
#    5.14000000e+02   9.80720000e+04   8.92000000e-01   1.38000000e+00
#    4.07600000e+03   4.75000000e-01   2.10270000e+04   3.42850000e+04
#    2.23000000e-01   5.49000000e+02   2.76000000e+00   3.36560000e+04
#    5.25700000e+03   9.50000000e+01   4.00000000e-02   1.89000000e+02
#    1.11940000e+04   5.30000000e-02   1.24000000e+02   4.33600000e+03
#    1.13000000e+00   1.72000000e-01   2.72000000e+02   6.02400000e+03
#    3.37940000e+04   2.49310000e+04   8.60000000e-02   1.85000000e+03
#    5.48000000e+03   1.59410000e+04   1.44000000e-01   2.98800000e+00
#    7.00000000e+01   5.48100000e+03   5.90000000e-03   2.07800000e+04
#    6.18200000e+03   1.50990000e+04   7.96000000e-01   8.62000000e-01
#    2.12800000e+00   3.33000000e-01   6.00000000e-03   2.61000000e-01
#    1.14910000e+04   1.12400000e+03   2.09000000e-01   8.86900000e+03
#    5.86400000e+03   5.53400000e+03   4.50000000e-03   1.96300000e+03
#    2.53000000e-01   3.44000000e-01   1.50600000e+03   1.73400000e+03
#    4.90360000e+04   1.62650000e+04   4.35000000e-01   3.73000000e-01
#    2.42000000e-01   5.80000000e-02]
# Currency ['USD']
# LeaseContractLength ['1yr' '3yr' None]
# PurchaseOption ['Partial Upfront' 'All Upfront' 'No Upfront' None]
# OfferingClass ['standard' 'convertible' None]
# Product_Family ['Compute Instance']
# serviceCode ['AmazonEC2']
# Location ['US East (Ohio)']
# Location_Type ['AWS Region']
# Instance_Type ['r4.large' 't2.large' 'i2.4xlarge' 'r3.xlarge' 'm4.large' 'c4.8xlarge'
#  'i3.2xlarge' 'm4.10xlarge' 'c4.large' 't2.medium' 'r3.2xlarge'
#  'd2.2xlarge' 'r4.2xlarge' 'd2.xlarge' 'i3.xlarge' 'm4.xlarge' 'r3.large'
#  'i3.4xlarge' 'r4.4xlarge' 'r4.16xlarge' 'r3.4xlarge' 'i2.xlarge'
#  'i2.8xlarge' 'c4.xlarge' 'm4.4xlarge' 'r4.xlarge' 't2.nano' 'i3.8xlarge'
#  't2.xlarge' 'c4.4xlarge' 't2.2xlarge' 'x1.16xlarge' 'r3.8xlarge'
#  'm4.2xlarge' 'd2.4xlarge' 'm4.16xlarge' 'r4.8xlarge' 'x1.32xlarge'
#  't2.micro' 'i3.16xlarge' 'd2.8xlarge' 'i3.large' 'i2.2xlarge' 't2.small'
#  'c4.2xlarge']
# Current_Generation ['Yes' None]
# Instance_Family ['Memory optimized' 'General purpose' 'Storage optimized'
#  'Compute optimized']
# vCPU [   2.   16.    4.   36.    8.   40.   64.   32.    1.  128.]
# Physical_Processor ['Intel Xeon E5-2686 v4 (Broadwell)' 'Intel Xeon Family'
#  'Intel Xeon E5-2670 v2 (Ivy Bridge)' 'Intel Xeon E5-2676 v3 (Haswell)'
#  'Intel Xeon E5-2666 v3 (Haswell)' 'Intel Xeon E5-2676v3 (Haswell)'
#  'High Frequency Intel Xeon E7-8880 v3 (Haswell)']
# Clock_Speed ['2.3 GHz' 'Up to 3.0 GHz' '2.5 GHz' '2.4 GHz' '2.9 GHz' 'Up to 3.3 GHz'
#  '2.4  GHz']
# Memory ['15.25 GiB' '8 GiB' '122 GiB' '30.5 GiB' '60 GiB' '61 GiB' '160 GiB'
#  '3.75 GiB' '4 GiB' '16 GiB' '488 GiB' '244 GiB' '7.5 GiB' '64 GiB'
#  '0.5 GiB' '30 GiB' '32 GiB' '976 Gib' '256 GiB' '1,952 Gib' '1 GiB'
#  '2 GiB' '15 GiB']
# Storage ['EBS only' '4 x 800 SSD' '1 x 80 SSD' '1 x 160 SSD' '6 x 2000 HDD'
#  '3 x 2000 HDD' '1 x 32 SSD' '1 x 320 SSD' '1 x 800 SSD' '8 x 800 SSD'
#  '1 x 1,920' '2 x 320 SSD' '12 x 2000 HDD' '2 x 1,920' '24 x 2000 HDD'
#  '2 x 800 SSD']
# Network_Performance ['Up to 10 Gigabit' 'Low to Moderate' 'High' 'Moderate' '10 Gigabit'
#  '20 Gigabit' 'Low']
# Processor_Architecture ['64-bit' '32-bit or 64-bit']
# Storage_Media [None]
# Volume_Type [None]
# Max_Volume_Size [None]
# Max_IOPS_volume [None]
# Max_IOPS_Burst_Performance [None]
# Max_throughput_volume [None]
# Provisioned [None]
# Tenancy ['Shared']
# EBS_Optimized [None]
# Operating_System ['Linux']
# License_Model ['No License required']
# Group [None]
# Group_Description [None]
# Transfer_Type [None]
# From_Location [None]
# From_Location_Type [None]
# To_Location [None]
# To_Location_Type [None]
# usageType ['USE2-BoxUsage:r4.large' 'USE2-BoxUsage:t2.large'
#  'USE2-BoxUsage:i2.4xlarge' 'USE2-BoxUsage:r3.xlarge'
#  'USE2-BoxUsage:m4.large' 'USE2-BoxUsage:c4.8xlarge'
#  'USE2-BoxUsage:i3.2xlarge' 'USE2-BoxUsage:m4.10xlarge'
#  'USE2-BoxUsage:c4.large' 'USE2-BoxUsage:t2.medium'
#  'USE2-BoxUsage:r3.2xlarge' 'USE2-BoxUsage:d2.2xlarge'
#  'USE2-BoxUsage:r4.2xlarge' 'USE2-BoxUsage:d2.xlarge'
#  'USE2-BoxUsage:i3.xlarge' 'USE2-BoxUsage:m4.xlarge'
#  'USE2-BoxUsage:r3.large' 'USE2-BoxUsage:i3.4xlarge'
#  'USE2-BoxUsage:r4.4xlarge' 'USE2-BoxUsage:r4.16xlarge'
#  'USE2-BoxUsage:r3.4xlarge' 'USE2-BoxUsage:i2.xlarge'
#  'USE2-BoxUsage:i2.8xlarge' 'USE2-BoxUsage:c4.xlarge'
#  'USE2-BoxUsage:m4.4xlarge' 'USE2-BoxUsage:r4.xlarge'
#  'USE2-BoxUsage:t2.nano' 'USE2-BoxUsage:i3.8xlarge'
#  'USE2-BoxUsage:t2.xlarge' 'USE2-BoxUsage:c4.4xlarge'
#  'USE2-BoxUsage:t2.2xlarge' 'USE2-BoxUsage:x1.16xlarge'
#  'USE2-BoxUsage:r3.8xlarge' 'USE2-BoxUsage:m4.2xlarge'
#  'USE2-BoxUsage:d2.4xlarge' 'USE2-BoxUsage:m4.16xlarge'
#  'USE2-BoxUsage:r4.8xlarge' 'USE2-BoxUsage:x1.32xlarge'
#  'USE2-BoxUsage:t2.micro' 'USE2-BoxUsage:i3.16xlarge'
#  'USE2-BoxUsage:d2.8xlarge' 'USE2-BoxUsage:i3.large'
#  'USE2-BoxUsage:i2.2xlarge' 'USE2-BoxUsage:t2.small'
#  'USE2-BoxUsage:c4.2xlarge']
# operation ['RunInstances']
# Comments [None]
# Dedicated_EBS_Throughput ['400 Mbps' None '450 Mbps' '4000 Mbps' '1750 Mbps' '500 Mbps' '1600 Mbps'
#  '850 Mbps' '750 Mbps' '3500 Mbps' '3000 Mbps' '12000 Mbps' '2000 Mbps'
#  '800 Mbps' '7000 Mbps' '1000 Mbps' '10000 Mbps' '6000 Mbps' '14000 Mbps'
#  '425 Mbps']
# Enhanced_Networking_Supported ['Yes' None]
# GPU [ nan]
# Instance_Capacity_10xlarge [ nan]
# Instance_Capacity_2xlarge [ nan]
# Instance_Capacity_4xlarge [ nan]
# Instance_Capacity_8xlarge [ nan]
# Instance_Capacity_large [ nan]
# Instance_Capacity_medium [ nan]
# Instance_Capacity_xlarge [ nan]
# Intel_AVX_Available [None 'Yes']
# Intel_AVX2_Available [None 'Yes']
# Intel_Turbo_Available [None 'Yes']
# Physical_Cores [ nan]
# Pre_Installed_S_W [None]
# Processor_Features ['Intel AVX, Intel AVX2, Intel Turbo' 'Intel AVX; Intel Turbo'
#  'Intel AVX; Intel AVX2; Intel Turbo' None]
# Sockets [ nan]

# %%
grouped_by_term = compared_ec2_instances[
    compared_ec2_instances.Instance_Type == 't2.medium'].groupby(['OfferTermCode'])

# %%
grouped_by_term.groups
# Out:
# {'38NPMPTW36': Int64Index([27134, 122307], dtype='int64'),
#  '4NA7Y494T4': Int64Index([86477], dtype='int64'),
#  '6QCMYABX3D': Int64Index([59396, 81993], dtype='int64'),
#  'HU7G6KETJZ': Int64Index([1470, 68337], dtype='int64'),
#  'JRTCKXETXF': Int64Index([75011], dtype='int64'),
#  'MZU6U2429S': Int64Index([22923, 24698], dtype='int64'),
#  'NQ3QZPMQV9': Int64Index([52505, 141466], dtype='int64'),
#  'R5XV2EPZQZ': Int64Index([78948, 88825], dtype='int64'),
#  'Z2E3P23VKM': Int64Index([146520], dtype='int64')}

# %%
from pprint import pprint
for g in grouped_by_term.groups:
    pprint(grouped_by_term.get_group(g)[['OfferTermCode', 'RateCode', 'TermType', 
                                         'PurchaseOption', 'LeaseContractLength', 'OfferingClass', 
                                         'PricePerUnit', 'PriceDescription']].to_dict())
    print('-' * 100)
# Out:
# {'LeaseContractLength': {27134: '3yr', 122307: '3yr'},
#  'OfferTermCode': {27134: '38NPMPTW36', 122307: '38NPMPTW36'},
#  'OfferingClass': {27134: 'standard', 122307: 'standard'},
#  'PriceDescription': {27134: 'Upfront Fee',
#                       122307: 'Linux/UNIX (Amazon VPC), t2.medium '
#                               'instance-hours used this month'},
#  'PricePerUnit': {27134: 289.0, 122307: 0.010999999999999999},
#  'PurchaseOption': {27134: 'Partial Upfront', 122307: 'Partial Upfront'},
#  'RateCode': {27134: '2N2QH6UEJZ5GUPT8.38NPMPTW36.2TG2D8R56U',
#               122307: '2N2QH6UEJZ5GUPT8.38NPMPTW36.6YS6EN2CT7'},
#  'TermType': {27134: 'Reserved', 122307: 'Reserved'}}
# ----------------------------------------------------------------------------------------------------
# {'LeaseContractLength': {86477: '1yr'},
#  'OfferTermCode': {86477: '4NA7Y494T4'},
#  'OfferingClass': {86477: 'standard'},
#  'PriceDescription': {86477: 'Linux/UNIX (Amazon VPC), t2.medium '
#                              'instance-hours used this month'},
#  'PricePerUnit': {86477: 0.035999999999999997},
#  'PurchaseOption': {86477: 'No Upfront'},
#  'RateCode': {86477: '2N2QH6UEJZ5GUPT8.4NA7Y494T4.6YS6EN2CT7'},
#  'TermType': {86477: 'Reserved'}}
# ----------------------------------------------------------------------------------------------------
# {'LeaseContractLength': {59396: '1yr', 81993: '1yr'},
#  'OfferTermCode': {59396: '6QCMYABX3D', 81993: '6QCMYABX3D'},
#  'OfferingClass': {59396: 'standard', 81993: 'standard'},
#  'PriceDescription': {59396: 'USD 0.0 per Linux/UNIX (Amazon VPC), t2.medium '
#                              'instance-hour (or partial hour)',
#                       81993: 'Upfront Fee'},
#  'PricePerUnit': {59396: 0.0, 81993: 275.0},
#  'PurchaseOption': {59396: 'All Upfront', 81993: 'All Upfront'},
#  'RateCode': {59396: '2N2QH6UEJZ5GUPT8.6QCMYABX3D.6YS6EN2CT7',
#               81993: '2N2QH6UEJZ5GUPT8.6QCMYABX3D.2TG2D8R56U'},
#  'TermType': {59396: 'Reserved', 81993: 'Reserved'}}
# ----------------------------------------------------------------------------------------------------
# {'LeaseContractLength': {1470: '1yr', 68337: '1yr'},
#  'OfferTermCode': {1470: 'HU7G6KETJZ', 68337: 'HU7G6KETJZ'},
#  'OfferingClass': {1470: 'standard', 68337: 'standard'},
#  'PriceDescription': {1470: 'Linux/UNIX (Amazon VPC), t2.medium instance-hours '
#                             'used this month',
#                       68337: 'Upfront Fee'},
#  'PricePerUnit': {1470: 0.016, 68337: 140.0},
#  'PurchaseOption': {1470: 'Partial Upfront', 68337: 'Partial Upfront'},
#  'RateCode': {1470: '2N2QH6UEJZ5GUPT8.HU7G6KETJZ.6YS6EN2CT7',
#               68337: '2N2QH6UEJZ5GUPT8.HU7G6KETJZ.2TG2D8R56U'},
#  'TermType': {1470: 'Reserved', 68337: 'Reserved'}}
# ----------------------------------------------------------------------------------------------------
# {'LeaseContractLength': {75011: None},
#  'OfferTermCode': {75011: 'JRTCKXETXF'},
#  'OfferingClass': {75011: None},
#  'PriceDescription': {75011: '$0.047 per On Demand Linux t2.medium Instance '
#                              'Hour'},
#  'PricePerUnit': {75011: 0.047},
#  'PurchaseOption': {75011: None},
#  'RateCode': {75011: '2N2QH6UEJZ5GUPT8.JRTCKXETXF.6YS6EN2CT7'},
#  'TermType': {75011: 'OnDemand'}}
# ----------------------------------------------------------------------------------------------------
# {'LeaseContractLength': {22923: '3yr', 24698: '3yr'},
#  'OfferTermCode': {22923: 'MZU6U2429S', 24698: 'MZU6U2429S'},
#  'OfferingClass': {22923: 'convertible', 24698: 'convertible'},
#  'PriceDescription': {22923: 'Upfront Fee',
#                       24698: 'USD 0.0 per Linux/UNIX (Amazon VPC), t2.medium '
#                              'instance-hour (or partial hour)'},
#  'PricePerUnit': {22923: 743.0, 24698: 0.0},
#  'PurchaseOption': {22923: 'All Upfront', 24698: 'All Upfront'},
#  'RateCode': {22923: '2N2QH6UEJZ5GUPT8.MZU6U2429S.2TG2D8R56U',
#               24698: '2N2QH6UEJZ5GUPT8.MZU6U2429S.6YS6EN2CT7'},
#  'TermType': {22923: 'Reserved', 24698: 'Reserved'}}
# ----------------------------------------------------------------------------------------------------
# {'LeaseContractLength': {52505: '3yr', 141466: '3yr'},
#  'OfferTermCode': {52505: 'NQ3QZPMQV9', 141466: 'NQ3QZPMQV9'},
#  'OfferingClass': {52505: 'standard', 141466: 'standard'},
#  'PriceDescription': {52505: 'Upfront Fee',
#                       141466: 'USD 0.0 per Linux/UNIX (Amazon VPC), t2.medium '
#                               'instance-hour (or partial hour)'},
#  'PricePerUnit': {52505: 543.0, 141466: 0.0},
#  'PurchaseOption': {52505: 'All Upfront', 141466: 'All Upfront'},
#  'RateCode': {52505: '2N2QH6UEJZ5GUPT8.NQ3QZPMQV9.2TG2D8R56U',
#               141466: '2N2QH6UEJZ5GUPT8.NQ3QZPMQV9.6YS6EN2CT7'},
#  'TermType': {52505: 'Reserved', 141466: 'Reserved'}}
# ----------------------------------------------------------------------------------------------------
# {'LeaseContractLength': {78948: '3yr', 88825: '3yr'},
#  'OfferTermCode': {78948: 'R5XV2EPZQZ', 88825: 'R5XV2EPZQZ'},
#  'OfferingClass': {78948: 'convertible', 88825: 'convertible'},
#  'PriceDescription': {78948: 'Upfront Fee',
#                       88825: 'Linux/UNIX (Amazon VPC), t2.medium '
#                              'instance-hours used this month'},
#  'PricePerUnit': {78948: 378.0, 88825: 0.014},
#  'PurchaseOption': {78948: 'Partial Upfront', 88825: 'Partial Upfront'},
#  'RateCode': {78948: '2N2QH6UEJZ5GUPT8.R5XV2EPZQZ.2TG2D8R56U',
#               88825: '2N2QH6UEJZ5GUPT8.R5XV2EPZQZ.6YS6EN2CT7'},
#  'TermType': {78948: 'Reserved', 88825: 'Reserved'}}
# ----------------------------------------------------------------------------------------------------
# {'LeaseContractLength': {146520: '3yr'},
#  'OfferTermCode': {146520: 'Z2E3P23VKM'},
#  'OfferingClass': {146520: 'convertible'},
#  'PriceDescription': {146520: 'Linux/UNIX (Amazon VPC), t2.medium '
#                               'instance-hours used this month'},
#  'PricePerUnit': {146520: 0.032000000000000001},
#  'PurchaseOption': {146520: 'No Upfront'},
#  'RateCode': {146520: '2N2QH6UEJZ5GUPT8.Z2E3P23VKM.6YS6EN2CT7'},
#  'TermType': {146520: 'Reserved'}}
# ----------------------------------------------------------------------------------------------------
